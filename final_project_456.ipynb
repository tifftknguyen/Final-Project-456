# %% [markdown]
# <a href="https://colab.research.google.com/github/tifftknguyen/Final-Project-456/blob/main/final_project_456.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tiffany Nguyen
# # Giselle Hernandez
# # CECS 456 Sec 01 - Machine Learning
# # Professor Wenlu Zhang
# # Final Project

# %%
! pip install -q kaggle

# %%
import kagglehub

# %%
path = kagglehub.dataset_download("prasunroy/natural-images")
# Out:
# Using Colab cache for faster access to the 'natural-images' dataset.

# %%
print("Path to dataset files:", path)
# Out:
# Path to dataset files: /kaggle/input/natural-images

# %%
# INITIAL SETUP

import os, tensorflow as tf
from tensorflow.keras import layers, models

# imports based on the labs & hw
import sklearn
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
data_dir = path

# %%
# SMALLEST AMOUNT OF PARAMETERS FOR THE SAKE OF TESTING & TROUBLESHOOTING

IMG_SIZE   = (64, 64)
BATCH_SIZE = 8
SEED       = 42
EPOCHS     = 1

# %%
# TRAIN & TEST

# %%
# BATCHING

# %%
# MODEL 1: FC/MLP (FULLY CONNECTED NETWORK)

# %%
# MODEL 2: SIMPLE CNN

# %%
# PREDICTIONS
